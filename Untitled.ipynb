# %%
import requests
from io import string IO
url = "https://api.themoviedb.org/3/movie/top_rated?api_key=b2cb7ba21343d87c5624b90f86f6fa87&language=en-US&page=1"
headers = {"1,2,3,4,5"}
req = requests.get(url,headers = headers)
data = string IO(req.test)
pd.read_csv(data)
# Out:
#   Cell In[6], line 2
#     from io import string IO
#                           ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
